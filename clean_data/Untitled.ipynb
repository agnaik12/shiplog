# %%
import pandas as pd
df = pd.read_parquet("oldweather_cleaned_dedup.parquet")
print(df.head())
print(df.info())

# %%
conda install -c conda-forge pyarrow

# %%
import pandas as pd

df = pd.read_parquet("oldweather_cleaned_dedup.parquet", engine="pyarrow")
print(df.head())
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_parquet("oldweather_cleaned_dedup.parquet", engine="pyarrow")
#       4 print(df.head())
#       5 print(df.info())
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/io/parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# ...

# %%
import pyarrow.parquet as pq

pf = pq.ParquetFile("oldweather_cleaned_dedup.parquet")
print(pf.schema)
print(pf.metadata)
# Out:
# ...
# required group field_id=-1 schema {
#   optional double field_id=-1 lon;
#   optional double field_id=-1 temp_wet;
#   optional double field_id=-1 baro;
#   optional binary field_id=-1 hour (String);
#   optional double field_id=-1 lat;
#   optional double field_id=-1 temp_dry;
#   optional binary field_id=-1 date (String);
#   optional binary field_id=-1 ship (String);
#   optional binary field_id=-1 source_file (String);
#   optional binary field_id=-1 course (String);
#   optional binary field_id=-1 wind_dir_true (String);
#   optional double field_id=-1 clear_sky;
#   optional double field_id=-1 wind_kts;
#   optional binary field_id=-1 wind_dir_mag (String);
#   optional binary field_id=-1 orig_lat (String);
#   optional binary field_id=-1 orig_course (String);
#   optional binary field_id=-1 clouds (String);
#   optional binary field_id=-1 distance (String);
#   optional binary field_id=-1 ice_1 (String);
#   optional binary field_id=-1 ice_2 (String);
# ...

# %%
import pyarrow.parquet as pq

path = "oldweather_cleaned_dedup.parquet"
pf = pq.ParquetFile(path)

print("Row groups:", pf.num_row_groups)

for i in range(pf.num_row_groups):
    try:
        table = pf.read_row_group(i)
        print(f"Row group {i}: OK, rows={table.num_rows}")
    except Exception as e:
        print(f"Row group {i}: FAILED")
        print(e)
# Out:
# Row groups: 2
# Row group 0: FAILED
# Repetition level histogram size mismatch
# Row group 1: FAILED
# Repetition level histogram size mismatch

# %%
import pandas as pd

df = pd.read_parquet(
    "oldweather_cleaned_dedup.parquet",
    columns=core_cols,
    engine="pyarrow"
)

print(df.head())
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 import pandas as pd
#       3 df = pd.read_parquet(
#       4     "oldweather_cleaned_dedup.parquet",
# ----> 5     columns=core_cols,
#       6     engine="pyarrow"
#       7 )
#       9 print(df.head())
#      10 print(df.info())
#
# NameError: name 'core_cols' is not defined

# %%
import pandas as pd

core_cols = [
    "datetime",
    "date",
    "ship",
    "lat",
    "lon",
    "temp_dry",
    "temp_wet",
    "temp_water",
    "baro",
    "wind_kts",
    "weather",
    "clouds",
    "ice_1",
    "ice_2",
    "ice_log",
    "people",
    "flora_fauna",
    "animals",
]

df = pd.read_parquet(
    "oldweather_cleaned_dedup.parquet",
    columns=core_cols,
    engine="pyarrow"
)

print(df.head())
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 24
#       1 import pandas as pd
#       3 core_cols = [
#       4     "datetime",
#       5     "date",
#    (...)     21     "animals",
#      22 ]
# ---> 24 df = pd.read_parquet(
#      25     "oldweather_cleaned_dedup.parquet",
#      26     columns=core_cols,
#      27     engine="pyarrow"
#      28 )
#      30 print(df.head())
#      31 print(df.info())
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/io/parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
# ...

# %%
pip install duckdb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 46.9 MB/s  0:00:0045.6 MB/s eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb

df = duckdb.sql("""
    SELECT
        datetime,
        date,
        ship,
        lat,
        lon,
        temp_dry,
        temp_wet,
        temp_water,
        baro,
        wind_kts,
        weather,
        clouds,
        ice_1,
        ice_2,
        ice_log,
        people,
        flora_fauna,
        animals
    FROM read_parquet('oldweather_cleaned_dedup.parquet')
    LIMIT 1000
""").df()

print(df.head())
print(df.info())
# Out:
#              datetime        date  ship    lat     lon  temp_dry  temp_wet  \
# 0 1943-01-01 00:00:00  1943-01-01  Adak  51.88 -176.65      37.4      34.5
# 1 1943-01-01 01:00:00  1943-01-01  Adak  51.88 -176.65      37.4      34.5
# 2 1943-01-01 02:00:00  1943-01-01  Adak  51.88 -176.65      37.4      36.9
# 3 1943-01-01 03:00:00  1943-01-01  Adak  51.88 -176.65      37.4      36.9
# 4 1943-01-01 04:00:00  1943-01-01  Adak  51.88 -176.65      37.4      36.5
#
#    temp_water   baro  wind_kts weather clouds ice_1 ice_2 ice_log people  \
# 0         NaN  29.82       NaN    None   None  None  None    None   None
# 1         NaN  29.79       NaN    None   None  None  None    None   None
# 2         NaN  29.75       NaN    None   None  None  None    None   None
# 3         NaN  29.70       NaN    None   None  None  None    None   None
# 4         NaN  29.66       NaN    None   None  None  None    None   None
#
#   flora_fauna animals
# 0        None    None
# 1        None    None
# ...

# %%
pip install duckdb pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
python scripts/build_graph_json.py \
  --input oldweather_cleaned_dedup.parquet \
  --output public/graph_data.json
# Out:
#   Cell In[10], line 1
#     python scripts/build_graph_json.py \
#            ^
# SyntaxError: invalid syntax
